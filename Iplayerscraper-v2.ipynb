# %%
# Imports

import mechanicalsoup
import json
import hashlib
from bs4 import BeautifulSoup
import sys

# %%
# variable instantiation

BASE_URL = 'https://www.bbc.co.uk'

SCRAPING_SUFFIX = '/iplayer/a-z/'

browser = mechanicalsoup.StatefulBrowser()

# %%
# initail browser page

browser.open(BASE_URL + SCRAPING_SUFFIX)


navigation = browser.get_current_page().find('ul', attrs={'class': 'scrollable-nav__track'})

navigation_list = navigation.find_all('li')

navigation_list = [x.a['href'] for x in navigation_list if x.a is not None ]

print(navigation_list)
# Out:
# ['/iplayer/a-z/a', '/iplayer/a-z/b', '/iplayer/a-z/c', '/iplayer/a-z/d', '/iplayer/a-z/e', '/iplayer/a-z/f', '/iplayer/a-z/g', '/iplayer/a-z/h', '/iplayer/a-z/i', '/iplayer/a-z/j', '/iplayer/a-z/k', '/iplayer/a-z/l', '/iplayer/a-z/m', '/iplayer/a-z/n', '/iplayer/a-z/o', '/iplayer/a-z/p', '/iplayer/a-z/q', '/iplayer/a-z/r', '/iplayer/a-z/s', '/iplayer/a-z/t', '/iplayer/a-z/u', '/iplayer/a-z/v', '/iplayer/a-z/w', '/iplayer/a-z/x', '/iplayer/a-z/y', '/iplayer/a-z/z', '/iplayer/a-z/0-9']

# %%
def iplayer_atoz_page_extractor(program_selection):
    '''arguement is soup div tag for a program.
    Returns program title, program synopsis, no of
    episodes available, and the link to the latest episode'''
    # Program Title
    title = program_selection.find('p',
            attrs={'class':
                'list-content-item__title'}).get_text()
    # Program Synopsis
    synopsis = program_selection.find('p',
            attrs={'class':
                'list-content-item__synopsis'}).get_text()
    # Link to latest episode
    latest_episode_url = program_selection.find('a',
            href=True)['href']
    # Number of episodes available
    episodes_available = program_selection.find('div',
            attrs={'class': 'list-content-item__sublabels'})
    
    
    return title, synopsis, latest_episode_url

# %%
def get_page(browser, url):
            browser.open(url)
            return browser.get_current_page()

# %%
def programme_website_extractor(web_page):
    
    program_website_url = web_page.find('a',
            attrs={'class': 'lnk'},
            text='Programme website')['href']
    program_credits_url = web_page.find('a',
            attrs={'class': 'lnk'},
            text='Credits')
    
    credits_available = bool(program_credits_url)
    
    if credits_available:
        program_credits_url = program_credits_url['href']
    
    return program_website_url, program_credits_url, credits_available

# %%
def episode_page_extractor(web_page, credits_available):
    
    # Credits
    if credits_available:
        credits = web_page.find('table', attrs={'class': 'table'})
        if credits:
            credits_dict = {}
            for row in credits.find_all('tr'):
                person = row.find_all('span')
                if len(person) > 1:
                    json_credits = [x.get_text() for x in person]
                    credits_dict[json_credits[0]] = json_credits[1]

    # Genre and format
    
    genre_format = web_page.find(
        'div', attrs={'class': 'footer__similar b-g-p component'})
    
    if genre_format is None:
        genre_format = web_page.find('div', attrs={'class': 'islet--horizontal footer__programmes footer__service-island'})

    if genre_format is not None:
        sim = genre_format.find_all('div')
        genre_format_list = []

        for i in sim:
            genre_format_list.append(
                [[x.get_text(), x['href']] for x in i.find_all('a')])
            
        genre = []
        sub_genre = []
        prog_frmat = []
        genre_format_dict = {'genre': {}}

        for i in range(len(genre_format_list)):
            for j in range(len(genre_format_list[i])):
                if i == 0:
                    if j < 1:
                        genre.append(genre_format_list[i][j])
                        genre_format_dict['genre'].update({'main': {str(j): genre_format_list[i][j][0],
                                                              'link': genre_format_list[i][j][1]}})
                    else: 
                        sub_genre.append(genre_format_list[i][j])
                        genre_format_dict['genre'].update({'sub_genre': {str(j): genre_format_list[i][j][0],
                                                                   'link': genre_format_list[i][j][1]}})
                else:
                    if j < 1:
                        genre_format_dict.update({'format': {str(j): genre_format_list[i][j][0],
                                                       'link': genre_format_list[i][j][1]}})
                    else:
                        genre_format_dict['format'].update({'sub_format': {str(j): genre_format_list[i][j][0],
                                                                     'link': genre_format_list[i][j][1]}})

        print(genre_format_dict)
    
    # get time left to watch
        
    left_to_watch = web_page.find(
        'div', attrs={'class': 'grid 1/3@bpw 1/4@bpe'})

    if left_to_watch is not None:
        left_to_watch_items = left_to_watch.find_all(
            'p', attrs={'class': 'episode-panel__meta'})

        if left_to_watch.find(
                'div', attrs={'class': "episode-panel__meta"}) is None:
            if left_to_watch_items[0].span is None:
                days_left = left_to_watch_items[0].get_text()
            else:
                days_left = left_to_watch_items[0].span.get_text()
            duration = left_to_watch_items[1].get_text()

            print('Left to watch: ', days_left,'duration: ' ,duration)
    
    # get long synopsis
    
    long_synopsis = web_page.find(
        'div', attrs={'class': 'synopsis-toggle__long'})

    if long_synopsis is not None:
        long_synopsis_paragraphs = [
            x.get_text() for x in long_synopsis.find_all('p')
        ]

        print('long_synopsis: ',long_synopsis_paragraphs)
    
    # Broadcast information
    main_broadcast = web_page.find(
        'div',
        attrs={
            'class':
            'grid 1/3@bpw2 1/3@bpe map__column map__column--2 map__column--last'
        })

    if main_broadcast is not None:
        date_last_aired = main_broadcast.find(
            'span',
            attrs={'class': 'broadcast-event__date text-base timezone--date'})
        time_last_aired = main_broadcast.find(
            'span', attrs={'class': 'timezone--time'})
        channel = main_broadcast.find(
            'div',
            attrs={
                'class':
                'programme__service box-link__elevated micro text--subtle'
            })
        if channel is not None:
            channel_text = channel.find('a').get_text()
            print('Channel: ', channel_text)
        if channel is not None:
            channel_link = channel.find('a')['href']
            print('Channel link: ', channel_link)
        if date_last_aired is not None:
            date_last_aired = date_last_aired.get_text()
            print('date_aired: ', date_last_aired)
        if time_last_aired is not None:
            time_last_aired = time_last_aired.get_text()
            print('time_aired: ', time_last_aired)
    
    # build dictionary 
        
    return 0

# %%
def recommendation_extraction(web_page):
    if web_page is not None:
        page_items = web_page.find('ol', attrs={'class': 'highlight-box-wrapper'})
        print('found list of recommendations')
        if page_items is not None: 
            list_items = page_items.find_all('li')
            for item in list_items:
                item_info = item.find('div', attrs={'class': 'programme__body'})
                link_1 = item_info.h4.a['href']
                link_2 = item_info.h4.a['resource']
                title = item_info.h4.a.get_text()
                synop = item_info.p.get_text()
                
                print('recommendations:', link_1, link_2, 'title: ',title, synop)

# %%
def episode_available_extraction(web_page):
    episodes_link = web_page.find(
        'a', attrs={
            'class': 'br-nav__link',
            'data-linktrack': 'nav_episodes'
        })
    
    if episodes_link is not None:
        episodes_link = episodes_link['href']

        print(episodes_link)
    
        episodes_page = get_page(browser, BASE_URL + episodes_link)
        
        episode_list_extractor(episodes_page)
        
        episode_pagination = episodes_page.find('ol', attrs={'class': 'nav nav--banner pagination delta'})
        
        # TODO loop through pagination
        # if present
        if episode_pagination:
            page_list = pagination.find_all('li', attrs={'class': 'pagination__page'})
            page_links = [x.a['href'] for x in page_list if x.a is not None]
            
            for endpoint in page_links:
                url = curr_url + endpoint

                browser.open(url)

                episodes_page = browser.get_current_page()
                episode_list_extractor(episodes_page)

# %%
def episode_list_extractor(web_page):
    episodes_available_list = web_page.find(
            'div', attrs={'class': 'br-box-page programmes-page'})
    episodes_container_list = episodes_available_list.find_all(
        'div',
        attrs={
            'class':
            'programme programme--tv programme--episode block-link highlight-box--list br-keyline br-blocklink-page br-page-linkhover-onbg015--hover'
        })

    available_episodes = web_page.find('span', attrs={'class': 'hidden grid-visible@bpb2 grid-visible@bpw'})
    print('available episodes: ', available_episodes.get_text())

    #TODO: fix this implimentation
    for item in episodes_container_list:
        # link
        item_headder = item.find(
            'div', attrs={'class': 'cta cta__overlay'})
        item_link = item_headder.a['href']
        # time left
        item_time_left = item_headder.a['title']
        # title
        item_body = item.find('div', attrs={'class': 'programme__body'})

        print(item_link, item_time_left)

        if item_body is not None:
            # num of episodes
            try: 
                episode_oneline_synopsis = item_body.p.get_text()
                print('episode_oneline_synopsis: ' ,episode_oneline_synopsis)
            except:
                pass
            try:
                episode_no = item_body.p.abbr['title']
                print('episode_no: ', episode_no)
            except:
                pass
            try:
                episode_title = item_body.find('span', attrs={'class': 'programme__title gamma'}).get_text()
                print(episode_title)
            except:
                pass

# %%
def upcoming_episodes():
    next_on_suffix = 'broadcasts/upcoming/'
    browser.open( + next_on_suffix)
    next_on = browser.get_current_page()
    next_on_section = next_on.find('ol', attrs={'class':'highlight-box-wrapper'}) 
    
    next_up_dict = {}
    
    for item in next_on_section.find_all('li'):
        broadcast_info = item.find('div', attrs={'class':'programme__body programme__body--flush'})
        broadcast_info_tag = broadcast_info.find('div', attrs={'class': 'broadcast-event__time beta'})
        
        broadcast_date = broadcast_info_tag['title']
        broadcast_day = broadcast_info_tag.find('span', attrs={'class':'broadcast-event__date text-base timezone--date'}).get_text()
        broadcast_time = broadcast_info_tag.find('span',attrs = {'class': 'timezone--time'}).get_text()
        
        broadcast_channel = broadcast_info.find('div', attrs={'class': 'programme__service box-link__elevated micro text--subtle'})

        channel = broadcast_channel.a.get_text()
        channel_url = broadcast_channel.a['href']
        
        program_info = item.find('div', attrs={'class': 'grid 7/12 2/3@bpb2 3/4@bpw 5/6@bpw2 5/6@bpe'})
        program_title_info = program_info.a
        
        program_id = program_info.div['data-pid']
        program_link = program_title_info['href']
        program_title = program_title_info.find('span', attrs={'class': 'programme__title gamma'}).get_text()
        series = program_title_info.find('span', attrs={'class': 'programme__subtitle centi'}).get_text()
        program_synopsis = program_info.p.get_text()
        
        next_up_dict[program_id] = {'program_title': program_title.encode('utf-8'),
                                    'series': series.encode('utf-8'),
                                    'program_synopsis': program_synopsis.encode('utf-8').strip(),
                                    'program_link': program_link.encode('utf-8'),
                                    'channel': {'name': channel.encode('utf-8'),
                                              'link': channel_link.encode('utf-8')},
                                    'broadcast': {'date': broadcast_date.encode('utf-8'),
                                                 'day': broadcast_day.encode('utf-8'),
                                                 'time': broadcast_time.encode('utf-8')}}
        
        
    print(next_up_dict)

# %%
for suffix in navigation_list:
    browser.open(BASE_URL + suffix)
    
    program_selection = browser.get_current_page().find_all(
    'li', attrs={"class": "grid__item"})
    
    for program_box in program_selection: 
        program_title, program_synopsis, latest_episode_url = iplayer_atoz_page_extractor(program_box) 
        
        print(program_title, program_synopsis, latest_episode_url)
        
        # get latest url page
        
        latest_episode_page = get_page(browser, BASE_URL + latest_episode_url)
        
        program_website_url, program_credits_url, credits_available = programme_website_extractor(latest_episode_page)
        print(program_website_url, program_credits_url, credits_available)
        
        if credits_available:
            program_website_page = get_page(browser, BASE_URL + program_credits_url)
        else: 
            program_website_page = get_page(browser, BASE_URL + program_website_url)
        
        # TODO add program webpage extraction for programs without credits for genre 
        
        # TODO assign variables from this function
        episode_page_extractor(program_website_page, credits_available)
        
        recommendation_page = get_page(browser, BASE_URL + program_website_url + '/recommendations')
        recommendation_extraction(recommendation_page)
        
        # TODO assign variables
        episode_available_extraction(get_page(browser, BASE_URL + program_website_url))
# Out:
# (u'Abadas', u'Rhaglen animeiddio i blant ifanc yn canolbwyntio ar gyflwyno geiriau newydd. Animation ...', '/iplayer/episode/p02fbwcv/abadas-trwmped')
# ('/programmes/p02b4jth', None, False)
# {'genre': {'main': {'0': u"Children's", 'link': '/programmes/genres/childrens'}}}
# found list of recommendations
# ('recommendations:', '/programmes/p02b4sp5', 'https://www.bbc.co.uk/programmes/p02b4sp5', 'title: ', u'  Yn yr Ardd  \u2014 Cyfres 2, Tylwyth Teg ', u' Mae dant Fflach yn rhydd. Tybed a fydd y tylwyth teg yn galw heibio? Fflach has a wobbl... ')
# ('recommendations:', '/programmes/p04x702k', 'https://www.bbc.co.uk/programmes/p04x702k', 'title: ', u'  Ynys Broc M\xf4r Lili  \u2014 Cyfres 1, Harbwr cwcis ', u" Mae Lili'n dod o hyd i declyn torri bisgedi ar y traeth ac yn penderfynu y byddai'n bra... ")
# ('recommendations:', '/programmes/p06y72c5', 'https://www.bbc.co.uk/programmes/p06y72c5', 'title: ', u"  Blero'n Mynd i Ocido  \u2014 Cyfres 2, 9 ", u" Pan fo'r haul yn diflannu, mae Blero a'i ffrindiau'n gwibio i'r gofod i weld beth sy'n ... ")
# ('recommendations:', '/programmes/p06c5y4b', 'https://www.bbc.co.uk/programmes/p06c5y4b', 'title: ', u"  Patr\xf4l Pawennau  \u2014 Cyfres 2, Cwn a'r cathod bach drygionus ", u' Mae grwp o gathod anhapus yn gwneud llanast ym Mhorth yr Haul.  Galwch am y cwn! A grou... ')
# ('recommendations:', '/programmes/p06ppl22', 'https://www.bbc.co.uk/programmes/p06ppl22', 'title: ', u'  Amser Maith Maith yn \xd4l  \u2014 Amser Maith Yn Ol, Amser Maith Yn \xd4l ', u" Stori o Oes y Tuduriaid sydd gan Tadcu i Ceti heddiw yn 'Amser Maith Maith yn \xf4l'. Gran... ")
# Crwban y Môr
# ('https://www.bbc.co.uk/iplayer/episode/p02dtdtl', u'10 o ddyddiau ar \xf4l i wylio (Sad 09 Chwefror 2019, 09:00)')
# ('episode_oneline_synopsis: ', u"\nMae un o'r Abadas yn mynd ar antur gyffrous wrth edrych am rywbeth si\xe2p cylch gydag aro...\n")
# Oren
# ('https://www.bbc.co.uk/iplayer/episode/p02db5b3', u'8 o ddyddiau ar \xf4l i wylio (Iau 07 Chwefror 2019, 09:00)')
# ('episode_oneline_synopsis: ', u"\nYmunwch \xe2'r Abadas ar antur arbennig unwaith eto! 'Bwi' yw'r gair newydd heddiw. Today'...\n")
# Bwi
# ('https://www.bbc.co.uk/iplayer/episode/p02db4dt', u'3 o ddyddiau ar \xf4l i wylio (Sad 02 Chwefror 2019, 09:00)')
# ('episode_oneline_synopsis: ', u"\nMae'r Abadas wedi adeiladu ffau yn y ty i'w cadw'n sych rhag glaw papur Seren. Mae gan ...\n")
# Ambarél
# (u'The ABC Murders', u"It's 1933, and an older and greyer Hercule Poirot must take matters into his own hands.", '/iplayer/episode/b0bxc1sn/the-abc-murders-series-1-episode-3')
# ('/programmes/b0bxbvtl', '/programmes/b0bxc1sn#credits', True)
# {'genre': {'main': {'0': u'Drama', 'link': '/programmes/genres/drama'}, 'sub_genre': {'1': u'Crime', 'link': '/programmes/genres/drama/crime'}}}
# ('Left to watch: ', u'1 month left to watch', 'duration: ', u'\n59 minutes\n            ')
# ('Channel: ', u'BBC One')
# ('Channel link: ', 'https://www.bbc.co.uk/bbcone')
# ('date_aired: ', u'Fri 28 Dec 2018')
# ('time_aired: ', u'21:00')
# found list of recommendations
# ('recommendations:', '/programmes/b01mgz1c', 'https://www.bbc.co.uk/programmes/b01mgz1c', 'title: ', u'  All Good Things  ', u' Ryan Gosling plays a volatile man whose wife mysteriously disappears. ')
# ('recommendations:', '/programmes/b0c13qyn', 'https://www.bbc.co.uk/programmes/b0c13qyn', 'title: ', u'  Death in Paradise  \u2014 Series 8, Episode 3 ', u' 3/8 Jack and the team are mystified when a TV presenter is found drowned. ')
# ('recommendations:', '/programmes/b0c0r3vr', 'https://www.bbc.co.uk/programmes/b0c0r3vr', 'title: ', u'  Silent Witness  \u2014 Series 22, To Brighton, to Brighton: Part Two ', u' The team must unearth the connections between a diverse range of suspects. ')
# ('recommendations:', '/programmes/b0bxbkxc', 'https://www.bbc.co.uk/programmes/b0bxbkxc', 'title: ', u'  Luther  \u2014 Series 5, Episode 4 ', u' 4/4 Luther can no longer keep his troubles out of the case, as a macabre masterpiece unfolds. ')
# ('recommendations:', '/programmes/b0b98wf6', 'https://www.bbc.co.uk/programmes/b0b98wf6', 'title: ', u'  Hidden  \u2014 Series 1, Episode 6 ', u' 6/8 DI Cadi John realises that Endaf Elwy may have been wrongly accused of murder. ')
# ('recommendations:', '/programmes/b09vbbwh', 'https://www.bbc.co.uk/programmes/b09vbbwh', 'title: ', u'  Shakespeare & Hathaway - Private Investigators  \u2014 Series 1, Ill Met by Moonlight ', u' 10/10 Frank and Lu must recover a precious jewel and a rebellious teenager. ')
# ('recommendations:', '/programmes/b0byqhj2', 'https://www.bbc.co.uk/programmes/b0byqhj2', 'title: ', u'  Father Brown  \u2014 Series 7, The Honourable Thief ', u" 10/10 When Lady Felicia's home is threatened, Father Brown seeks help from an unlikely ally. ")
# ('recommendations:', '/programmes/b0bxc46g', 'https://www.bbc.co.uk/programmes/b0bxc46g', 'title: ', u'  The Blake Mysteries  \u2014 Series 1, Episode 2 ', u" 2/2 The police's suspicion is aroused by some articles about unsolved cases. ")
# ('recommendations:', '/programmes/b013rlr3', 'https://www.bbc.co.uk/programmes/b013rlr3', 'title: ', u'  Evil under the Sun  ', u' When a guest at an island resort is found murdered, Poirot (Peter Ustinov) investigates. ')
# ('recommendations:', '/programmes/b016r4hj', 'https://www.bbc.co.uk/programmes/b016r4hj', 'title: ', u'  Death on the Nile  ', u' Hercule Poirot (Peter Ustinov) investigates the murder of an heiress on a Nile cruise. ')
# /programmes/b0bxbvtl/episodes
# ('available episodes: ', u'(3)')
# ('https://www.bbc.co.uk/iplayer/episode/b0bxc1sn', '1 month left to watch (Thu 28 March 2019, 22:00)')
# ('episode_oneline_synopsis: ', u'\n3/3 Hercule faces a race against time as he realises that only he holds the key to the case.\n')
# ('episode_no: ', 'Episode 3 of 3')
# Episode 3
# ('https://www.bbc.co.uk/iplayer/episode/b0bxc1h2', '1 month left to watch (Thu 28 March 2019, 22:00)')
# ('episode_oneline_synopsis: ', u"\n2/3 As the ABC killer promises to spill more blood, Hercule's identity comes into question.\n")
# ('episode_no: ', 'Episode 2 of 3')
# Episode 2
# ('https://www.bbc.co.uk/iplayer/episode/b0bxbvkg', '1 month left to watch (Thu 28 March 2019, 22:00)')
# ('episode_oneline_synopsis: ', u'\n1/3 1933. Hercule Poirot receives letters threatening murder, but no-one will listen.\n')
# ('episode_no: ', 'Episode 1 of 3')
# Episode 1
# (u'Absolutely Fabulous: The Movie', u'Eddy and Patsy are still living the high life, but a setback sees them going on the run.', '/iplayer/episode/b08b7blz/absolutely-fabulous-the-movie')
# ('/programmes/b08b7blz', '/programmes/b08b7blz#credits', True)
# {'genre': {'main': {'0': u'Comedy', 'link': '/programmes/genres/comedy'}, 'sub_genre': {'1': u'Sitcoms', 'link': '/programmes/genres/comedy/sitcoms'}}, 'format': {'0': u'Films', 'link': '/programmes/formats/films'}}
# ('Left to watch: ', u'1 day left to watch', 'duration: ', u'\n1 hour, 31 minutes\n            ')
# ('long_synopsis: ', [u'Worried about her finances when her book fails to find a publisher, Patsy is given the tip that Kate Moss has left her PR company and will be looking for new representation. Things start to go awry when the plot to approach Kate goes horribly wrong, and Patsy and Edina find themselves vilified by the entire nation and having to flee the country.'])
# ('Channel: ', u'BBC One')
# ('Channel link: ', 'https://www.bbc.co.uk/bbcone')
# ('date_aired: ', u"New Year's Day 2019")
# ('time_aired: ', u'01:50')
# found list of recommendations
# ('recommendations:', '/programmes/p05dsqxl', 'https://www.bbc.co.uk/programmes/p05dsqxl', 'title: ', u'  Porridge  \u2014 Series 1, The Cake ', u' 2/6 Bad boy Dougie Parfitt wants a favour, and there is a new prison officer on the block. ')
# ('recommendations:', '/programmes/b0c07nyf', 'https://www.bbc.co.uk/programmes/b0c07nyf', 'title: ', u"  My Million Pound Menu  \u2014 Series 2, Baba G'S, KraPow, XXVI - New Asian ", u' An Indian burger stall, a Thai concept and an Indian-Nepalese pop-up seek investment. ')
# ('recommendations:', '/programmes/b0bvbd51', 'https://www.bbc.co.uk/programmes/b0bvbd51', 'title: ', u"  Nadiya's Party Feasts  ", u' It is the season to celebrate and Nadiya Hussain is sharing her favourite party dishes. ')
# ('recommendations:', '/programmes/b0bnfbtb', 'https://www.bbc.co.uk/programmes/b0bnfbtb', 'title: ', u'  Great British Menu  \u2014 Series 13, Banquet ', u' One chef is crowned Champion of Champions. ')
# ('recommendations:', '/programmes/b0b2sqh6', 'https://www.bbc.co.uk/programmes/b0b2sqh6', 'title: ', u'  Top of the Shop with Tom Kerridge  \u2014 Series 1, Final ', u' 8/8 The seven heat winners fight it out for the title best up-and-coming artisan. ')
# /programmes/b052hdnr/episodes
# ('available episodes: ', u'(1)')
# ('https://www.bbc.co.uk/iplayer/episode/b054fm6n', '6 days left to watch (Mon 04 February 2019, 13:00)')
# ('episode_oneline_synopsis: ', u"\n6/6 Rachel Khoo heads to Malaysia to explore one of the world's most exciting cuisines.\n")
# ('episode_no: ', 'Episode 6 of 6')
# Rachel Khoo's Malaysia
# (u'Adam Curtis', u'Documentary films by Adam Curtis.', '/iplayer/episode/p04b183c/adam-curtis-hypernormalisation')
# ('/programmes/p04bkttz', '/programmes/p04b183c#credits', True)
# {'genre': {'main': {'0': u'Factual', 'link': '/programmes/genres/factual'}, 'sub_genre': {'3': u'Politics', 'link': '/programmes/genres/factual/politics'}}, 'format': {'0': u'Documentaries', 'sub_format': {'1': u'Films', 'link': '/programmes/formats/films'}, 'link': '/programmes/formats/documentaries'}}
# ('long_synopsis: ', [u'We live in a time of great uncertainty and confusion. Events keep happening that seem inexplicable and out of control. Donald Trump, Brexit, the War in Syria, the endless migrant crisis, random bomb attacks. And those who are supposed to be in power are paralysed - they have no idea what to do.', u'This film is the epic story of how we got to this strange place. It explains not only why these chaotic events are happening - but also why we, and our politicians, cannot understand them.', u'It shows that what has happened is that all of us in the West - not just the politicians and the journalists and the experts, but we ourselves - have retreated into a simplified, and often completely fake version of the world. But because it is all around us we accept it as normal.', u'But there is another world outside. Forces that politicians tried to forget and bury forty years ago - that then festered and mutated - but which are now turning on us with a vengeful fury. Piercing though the wall of our fake world.'])
# found list of recommendations
# /programmes/p04bkttz/episodes
# ('available episodes: ', u'(2)')
# (u'A Day in the Life of Earth', u'Hannah Fry reveals how much the Earth can change in a single day.', '/iplayer/episode/m0001vjc/a-day-in-the-life-of-earth')
# ('/programmes/m0001vjc', None, False)
# {'genre': {'main': {'0': u'Factual', 'link': '/programmes/genres/factual'}, 'sub_genre': {'2': u'Science & Nature', 'link': '/programmes/genres/factual/scienceandnature'}}, 'format': {'0': u'Documentaries', 'link': '/programmes/formats/documentaries'}}
# ('Left to watch: ', u'2 days left to watch', 'duration: ', u'\n58 minutes\n            ')
# Sharon Morgan
# ('https://www.bbc.co.uk/iplayer/episode/p06x264m', u'4 wythnos ar \xf4l i wylio (Gwen 01 Mawrth 2019, 18:30)')
# ('episode_oneline_synopsis: ', u"\nNia Parry sy'n busnesa yn nhai rhai o enwogion Cymru yn y gyfres hon. Y tro hwn, cawn g...\n")
# Aled Hall
# ('https://www.bbc.co.uk/iplayer/episode/p06wmt7v', u'10 o ddyddiau ar \xf4l i wylio (Gwen 08 Chwefror 2019, 21:00)')
# ('episode_oneline_synopsis: ', u"\nNia Parry sy'n busnesan yn nhai rhai o enwogion Cymru yn y gyfres 'Adre'. Y tro hwn - y...\n")
# Elliw Gwawr
# ('https://www.bbc.co.uk/iplayer/episode/p06w41x8', u'3 o ddyddiau ar \xf4l i wylio (Gwen 01 Chwefror 2019, 21:00)')
# ('episode_oneline_synopsis: ', u"\nY tro hwn byddwn yn ymweld \xe2 chartref y ffermwr a'r cyflwynydd poblogaidd, Dai Jones. T...\n")
# Dai Jones
# (u'Adventure', u'Long-running travel programme', '/iplayer/episode/p00y1hbb/adventure-zambezi-3-livingstones-river')
# ('/programmes/p00y02bb', None, False)
# {'genre': {'main': {'0': u'Factual', 'link': '/programmes/genres/factual'}, 'sub_genre': {'1': u'Travel', 'link': '/programmes/genres/factual/travel'}}}
# found list of recommendations
# /programmes/p00y02bb/episodes
# ('available episodes: ', u'(9)')
# (u'The Adventures of Abney & Teal', u'Animated adventures of two friends who live on an island in the middle of the big city.', '/iplayer/episode/b01p1127/the-adventures-of-abney-teal-series-2-22-the-porridge-machine')
# ('/programmes/b01cc6m6', '/programmes/b01p1127#credits', True)
# found list of recommendations
# (u'Afoot Again In The Past', u"Investigating Britain's architectural heritage.", '/iplayer/episode/p03lxghc/afoot-again-in-the-past-ickworth-house')
# ('/programmes/p03lc0cb', '/programmes/p03lxghc#credits', True)
# {'genre': {'main': {'0': u'Factual', 'link': '/programmes/genres/factual'}, 'sub_genre': {'link': '/programmes/genres/factual/homesandgardens/homes', '4': u'Homes'}}}
# ('Left to watch: ', u'\n                                    Available now\n                            ', 'duration: ', u'\n5 minutes\n            ')
# ('Channel: ', u'BBC Two')
# ('Channel link: ', 'https://www.bbc.co.uk/bbctwo')
# ('date_aired: ', u'Fri 28 Feb 2003')
# ('time_aired: ', u'11:25')
# found list of recommendations
# /programmes/p03lc0cb/episodes
# ('available episodes: ', u'(6)')
# (u'Africa', u"Eye to eye with the unknown - the world's wildest continent.", '/iplayer/episode/b01rrxdh/africa-the-greatest-show-on-earth')
# ('/programmes/p010jc6p', '/programmes/b01rrxdh#credits', True)
# {'genre': {'main': {'0': u'Factual', 'link': '/programmes/genres/factual'}, 'sub_genre': {'3': u'Nature & Environment', 'link': '/programmes/genres/factual/scienceandnature/natureandenvironment'}}}
# ('Left to watch: ', u'10 months left to watch', 'duration: ', u'\n59 minutes\n            ')
# ('https://www.bbc.co.uk/iplayer/episode/b01rrxdh', '10 months left to watch (Wed 11 December 2019, 09:00)')
# ('episode_oneline_synopsis: ', u'\nBlack rhinos reveal a lighter side to their character as they gather around a waterhole.\n')
# The Greatest Show on Earth
# ('https://www.bbc.co.uk/iplayer/episode/b01qmbqn', '10 months left to watch (Wed 11 December 2019, 09:00)')
# ('episode_oneline_synopsis: ', u'\n6/6 David Attenborough meets a baby rhino and wonders what the future holds for it.\n')
# ('episode_no: ', 'Episode 6 of 6')
# The Future
# ('https://www.bbc.co.uk/iplayer/episode/b01qh31v', '10 months left to watch (Wed 11 December 2019, 09:00)')
# ('episode_oneline_synopsis: ', u'\n5/6 A look at how animals survive in the extreme environment of the Sahara Desert.\n')
# ('episode_no: ', 'Episode 5 of 6')
# Sahara
# ('https://www.bbc.co.uk/iplayer/episode/b01qb062', '10 months left to watch (Wed 11 December 2019, 09:00)')
# ('episode_oneline_synopsis: ', u'\n4/6 David Attenborough reveals the vibrant environment of southern Africa.\n')
# ('episode_no: ', 'Episode 4 of 6')
# Cape
# ('https://www.bbc.co.uk/iplayer/episode/b01q0t2r', '10 months left to watch (Wed 11 December 2019, 09:00)')
# ('episode_oneline_synopsis: ', u'\n3/6 A look at how animals stand up and fight for their patch in the Congo.\n')
# ('episode_no: ', 'Episode 3 of 6')
# Congo
# ('https://www.bbc.co.uk/iplayer/episode/b01pwtsj', '10 months left to watch (Wed 11 December 2019, 09:00)')
# ('episode_oneline_synopsis: ', u'\n2/6 David Attenborough looks at the unique and constantly changing landscape of East Africa.\n')
# ('episode_no: ', 'Episode 2 of 6')
# Savannah
# ('https://www.bbc.co.uk/iplayer/episode/p010jc6r', '10 months left to watch (Wed 11 December 2019, 09:00)')
# ('episode_oneline_synopsis: ', u"\n1/6 David Attenborough explores the wildlife of two deserts in Africa's south west corner.\n")
# ('episode_no: ', 'Episode 1 of 6')
# Kalahari
# (u'After the Battle', u'Noted war correspondents return to the WWII battlefields from where they had reported.', '/iplayer/episode/p008qcdh/after-the-battle-1-london-ed-murrow-reports')
# ('/programmes/p008pxhz', None, False)
# {'genre': {'main': {'0': u'Factual', 'link': '/programmes/genres/factual'}, 'sub_genre': {'1': u'History', 'link': '/programmes/genres/factual/history'}}}
# found list of recommendations
# /programmes/p008pxhz/episodes
# ('available episodes: ', u'(1)')
# (u'Ahoi!', u'Cyfres hwyliog ar gyfer plant meithrin yng nghwmni y m\xf4r-ladron Ben Dant a Cadi. Fun se...', '/iplayer/episode/p061t4sq/ahoi-cyfres-2018-ysgol-y-ffwrnes-llanelli')
# ('/programmes/p05rkd18', None, False)
# {'genre': {'main': {'0': u"Children's", 'link': '/programmes/genres/childrens'}}}
# found list of recommendations
# ('recommendations:', '/programmes/p04bxcwz', 'https://www.bbc.co.uk/programmes/p04bxcwz', 'title: ', u'  Gwdihw  \u2014 Cyfres 2016, Pennod 1 ', u' Megan Llyn fydd yn cwrdd \xe2 phob math o anifeiliaid, rhai gwyllt, rhai dof a rhai anhygo... ')
# ('/programmes/b08tbg4x', None, False)
# {'genre': {'main': {'0': u'Factual', 'link': '/programmes/genres/factual'}, 'sub_genre': {'2': u'Nature & Environment', 'link': '/programmes/genres/factual/scienceandnature/natureandenvironment'}}, 'format': {'0': u'Documentaries', 'link': '/programmes/formats/documentaries'}}
# found list of recommendations
# ('recommendations:', '/programmes/b08z93c8', 'https://www.bbc.co.uk/programmes/b08z93c8', 'title: ', u'  Dhan Uisge  \u2014 Series 1, Easdale ', u' Calum Maclean shares his passion for swimming in remote, cold rivers and lochs. ')
# ('recommendations:', '/programmes/b04jmmmy', 'https://www.bbc.co.uk/programmes/b04jmmmy', 'title: ', u"  Oir a' Chuain Shiair/Facing the Atlantic  \u2014 Episode 2 ", u' The wildlife and landscape of the coast of Europe. ')
# ('recommendations:', '/programmes/b01lb4vn', 'https://www.bbc.co.uk/programmes/b01lb4vn', 'title: ', u'  Natural World  \u2014 2012-2013, Tiger Island ', u' 2/10 Could a maverick millionaire be the saviour of the man-eating jungle tigers of Sumatra? ')
# ('recommendations:', '/programmes/b09qjlfs', 'https://www.bbc.co.uk/programmes/b09qjlfs', 'title: ', u'  Chris Packham: In Search of the Lost Girl  ', u' Chris Packham searches for a tribal girl he met in 1998 whose jungle home is under threat. ')
# ('recommendations:', '/programmes/p01npl5v', 'https://www.bbc.co.uk/programmes/p01npl5v', 'title: ', u'  Wild Brazil  \u2014 A Dangerous World ', u' 1/3 Young monkeys, otters and coatis take their first steps in a spectacular, perilous world. ')
# ('recommendations:', '/programmes/b07bkcvb', 'https://www.bbc.co.uk/programmes/b07bkcvb', 'title: ', u"  Nature's Epic Journeys  \u2014 Elephants ", u' 1/3 A team follows elephants coming together for a crucial annual gathering in Kenya. ')
# ('recommendations:', '/programmes/b011w3xm', 'https://www.bbc.co.uk/programmes/b011w3xm', 'title: ', u'  Coast  \u2014 Series 6, London to Antwerp ', u' 1/6 The team starts in London and then explores the curious coast of Belgium. ')
# ('recommendations:', '/programmes/p01hsd4k', 'https://www.bbc.co.uk/programmes/p01hsd4k', 'title: ', u"  Wild Burma: Nature's Lost Kingdom  \u2014 Episode 3 ", u' 3/3 The team search for tigers in northern Burma and in Karen State in the far south. ')
# ('recommendations:', '/programmes/b0520t2w', 'https://www.bbc.co.uk/programmes/b0520t2w', 'title: ', u"  Alaska: Earth's Frozen Kingdom  \u2014 Spring ", u' 1/3 A mother sea otter nurses her baby through the chilly days of early spring. ')
# ('recommendations:', '/programmes/b00c5n6g', 'https://www.bbc.co.uk/programmes/b00c5n6g', 'title: ', u'  Wild China  \u2014 Land of the Panda ', u" 5/6 A look at China's heartland, home to the giant panda and the golden snub-nosed monkey. ")
# /programmes/b08tbg4x/episodes
# ('available episodes: ', u'(2)')
# ('https://www.bbc.co.uk/iplayer/episode/b08tn62q', '25 days left to watch (Sat 23 February 2019, 22:00)')
# ('episode_oneline_synopsis: ', u'\n2/4 Niall Iain Macdonald and Calum Macaulay explore the Union Canal.\n')
# ('episode_no: ', 'Episode 2 of 4')
# Episode 2
# ('recommendations:', '/programmes/p06m0m7t', 'https://www.bbc.co.uk/programmes/p06m0m7t', 'title: ', u'  Peppa  \u2014 Series 3, Princess Peppa/A\u2019 Bhana-phrionnsa Peppa ', u' Adventures of a small pink cartoon pig and her family ')
# /programmes/b04xhzb3/episodes
# ('available episodes: ', u'(2)')
# ('https://www.bbc.co.uk/iplayer/episode/b04yq4zn', '29 days left to watch (Wed 27 February 2019, 19:00)')
# ('episode_oneline_synopsis: ', u'\n2/26 Amazing facts about Dotty, a spotted dolphin who lives with close family in the ocean.\n')
# ('episode_no: ', 'Episode 2 of 26')
# Dotty the Spotted Dolphin
# ('https://www.bbc.co.uk/iplayer/episode/b04xhv00', '22 days left to watch (Wed 20 February 2019, 19:00)')
# ('episode_oneline_synopsis: ', u'\n1/26 Amazing facts about Rogan, a young joey living in the Australian outback.\n')
# ('episode_no: ', 'Episode 1 of 26')
# Rogan the Red Kangaroo
# (u"Alaska: Earth's Frozen Kingdom", u'A look at the stories of pioneering Alaskans over the course of a year.', '/iplayer/episode/b0536hxc/alaska-earths-frozen-kingdom-3-winter')
# ('/programmes/b0520nyz', '/programmes/b0536hxc#credits', True)
# {'genre': {'main': {'0': u'Factual', 'link': '/programmes/genres/factual'}, 'sub_genre': {'2': u'Nature & Environment', 'link': '/programmes/genres/factual/scienceandnature/natureandenvironment'}}, 'format': {'0': u'Documentaries', 'link': '/programmes/formats/documentaries'}}
# ('Left to watch: ', u'11 months left to watch', 'duration: ', u'\n59 minutes\n            ')
# ('long_synopsis: ', [u"Alaska is one of the most iconic wildernesses on the planet - America's last frontier.", u"This three-part series follows a year in Alaska, revealing the stories of pioneering Alaskans, both animal and human, as they battle the elements and reap the benefits of nature's seasonal gold rush.", u'Alaska is huge - by far the biggest US state - and still one of the wildest places on earth. It has deep forests and vast mountain ranges, and a third of it sits above the Arctic Circle. The whole state goes through some of the most extreme seasonal changes: temperatures can reach into the 90s F (30s C) in the summer and can plummet to -80F (-60C) in the winter.', u'Yet plenty survives here - Alaska is home to some of the hardiest animals on the planet. Each one has its own quirky way of getting through the challenges of the seasons. Above all, this is a land of great characters.', u"Black bear cubs are faced with a daunting climb down from their tree den and a mother sea otter nurses her baby through the chilly days of early spring. Stealthy 50-tonne sperm whales steal fish from the end of fishermen's lines in an extraordinary marine 'heist', grizzly bears grow big on a sudden wealth of salmon, and a huge male moose finds unlikely ways to impress a female. Thousands of bald eagles gather for a winter feast, and arctic foxes risk everything to find food in the alien world of an oil boomtown. People, too, must go with the flow of the extreme seasons, facing winter storms at sea to catch snow crabs, rushing across ice rivers with teams of huskies and taking advantage of Alaska's endless summer daylight to grow world-class giant vegetables.", u'Surviving the bone-chilling cold, deadly blizzards and darkness of an Alaskan winter takes courage, cunning and remarkable endurance. In the raw beauty of windswept mountain peaks, icy tundra and snowbound forests, this is the story of the tough and resourceful characters that face up to the ultimate challenges of this untameable land.'])
# ('Channel: ', u'BBC Four')
# ('Channel link: ', 'https://www.bbc.co.uk/bbcfour')
# ('date_aired: ', u'Sat 20 Jan 2018')
# ('time_aired: ', u'20:00')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-fd21db59ff77> in <module>()
#      27         episode_page_extractor(program_website_page, credits_available)
#      28
# ---> 29         recommendation_page = get_page(browser, BASE_URL + program_website_url + '/recommendations')
#      30         recommendation_extraction(recommendation_page)
#      31
#
# <ipython-input-7-6828e7c96c7b> in get_page(browser, url)
#       1 def get_page(browser, url):
# ----> 2             browser.open(url)
#       3             return browser.get_current_page()
#
# /usr/local/lib/python2.7/site-packages/mechanicalsoup/stateful_browser.pyc in open(self, url, *args, **kwargs)
#     131             print(url)
#     132
# --> 133         resp = self.get(url, *args, **kwargs)
#     134         self.__state = _BrowserState(page=resp.soup, url=resp.url,
#     135                                      request=resp.request)
#
# /usr/local/lib/python2.7/site-packages/mechanicalsoup/browser.pyc in get(self, *args, **kwargs)
#     122             object with a *soup*-attribute added by :func:`add_soup`.
#     123         """
# --> 124         response = self.session.get(*args, **kwargs)
#     125         if self.raise_on_404 and response.status_code == 404:
#     126             raise LinkNotFoundError()
#
# /usr/local/lib/python2.7/site-packages/requests/sessions.pyc in get(self, url, **kwargs)
#     524
#     525         kwargs.setdefault('allow_redirects', True)
# --> 526         return self.request('GET', url, **kwargs)
#     527
#     528     def options(self, url, **kwargs):
#
# /usr/local/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     511         }
#     512         send_kwargs.update(settings)
# --> 513         resp = self.send(prep, **send_kwargs)
#     514
#     515         return resp
#
# /usr/local/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     621
#     622         # Send the request
# --> 623         r = adapter.send(request, **kwargs)
#     624
#     625         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# /usr/local/lib/python2.7/site-packages/urllib3/connectionpool.pyc in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /usr/local/lib/python2.7/site-packages/urllib3/connectionpool.pyc in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     377         try:
#     378             try:  # Python 2.7, use buffering of HTTP responses
# --> 379                 httplib_response = conn.getresponse(buffering=True)
#     380             except TypeError:  # Python 2.6 and older, Python 3
#     381                 try:
#
# /usr/local/Cellar/python@2/2.7.15_2/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1119
#    1120         try:
# -> 1121             response.begin()
#    1122             assert response.will_close != _UNKNOWN
#    1123             self.__state = _CS_IDLE
#
# /usr/local/Cellar/python@2/2.7.15_2/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in begin(self)
#     436         # read until we get a non-100 response
#     437         while True:
# --> 438             version, status, reason = self._read_status()
#     439             if status != CONTINUE:
#     440                 break
#
# /usr/local/Cellar/python@2/2.7.15_2/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in _read_status(self)
#     392     def _read_status(self):
#     393         # Initialize with Simple-Response defaults
# --> 394         line = self.fp.readline(_MAXLINE + 1)
#     395         if len(line) > _MAXLINE:
#     396             raise LineTooLong("header line")
#
# /usr/local/Cellar/python@2/2.7.15_2/Frameworks/Python.framework/Versions/2.7/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# /usr/local/Cellar/python@2/2.7.15_2/Frameworks/Python.framework/Versions/2.7/lib/python2.7/ssl.pyc in recv(self, buflen, flags)
#     770                     "non-zero flags not allowed in calls to recv() on %s" %
#     771                     self.__class__)
# --> 772             return self.read(buflen)
#     773         else:
#     774             return self._sock.recv(buflen, flags)
#
# /usr/local/Cellar/python@2/2.7.15_2/Frameworks/Python.framework/Versions/2.7/lib/python2.7/ssl.pyc in read(self, len, buffer)
#     657                 v = self._sslobj.read(len, buffer)
#     658             else:
# --> 659                 v = self._sslobj.read(len)
#     660             return v
#     661         except SSLError as x:
#
# KeyboardInterrupt:

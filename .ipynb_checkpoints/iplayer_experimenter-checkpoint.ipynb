# %%
import mechanicalsoup
import json
import hashlib
from bs4 import BeautifulSoup
import sys

BASE_URL = 'https://www.bbc.co.uk'

SCRAPING_SUFFIX = '/iplayer/a-z/'

browser = mechanicalsoup.StatefulBrowser()

# %%
# Dictionary to hold the data

program_data = {}

browser.open(BASE_URL + SCRAPING_SUFFIX)

selection = browser.get_current_page().find_all(
    'li', attrs={"class": "grid__item"})

navigation = browser.get_current_page().find('ul', attrs={'class': 'scrollable-nav__track'})

navigation_list = navigation.find_all('li')

navigation_list = [x.a['href'] for x in navigation_list if x.a is not None ]

print(navigation_list)
# Out:
# ['/iplayer/a-z/a', '/iplayer/a-z/b', '/iplayer/a-z/c', '/iplayer/a-z/d', '/iplayer/a-z/e', '/iplayer/a-z/f', '/iplayer/a-z/g', '/iplayer/a-z/h', '/iplayer/a-z/i', '/iplayer/a-z/j', '/iplayer/a-z/k', '/iplayer/a-z/l', '/iplayer/a-z/m', '/iplayer/a-z/n', '/iplayer/a-z/o', '/iplayer/a-z/p', '/iplayer/a-z/q', '/iplayer/a-z/r', '/iplayer/a-z/s', '/iplayer/a-z/t', '/iplayer/a-z/u', '/iplayer/a-z/v', '/iplayer/a-z/w', '/iplayer/a-z/y', '/iplayer/a-z/z', '/iplayer/a-z/0-9']

# %% [markdown]
# From the initial wep page with the list of programs collect the title and synopsis. Can also grab the number of episodes. Collect link for further extraction
#
# This section yields:
# - Title
# - Synopsis
# - Episode Link

# %%
for item in selection:
    title = item.find('p', attrs={"class": "list-content-item__title"})
    synopsis = item.find('p', attrs={'class': 'list-content-item__synopsis'})
    num_episodes_available = item.find(
        'div', attrs={'class': 'list-content-item__sublabels'})
    link = item.find('a', href=True)['href']
    print('link: ',link)
    print('title: ', title.get_text())
    print('synopsis: ', synopsis.get_text())
    
    
    '''
    Follow link for each program item
    '''
    
    browser.open(BASE_URL + link)
    page = browser.get_current_page()

    episode_page_url = page.find('a', attrs={'class': 'lnk'}, text='Credits')
    if episode_page_url is None:
        episode_page_url = browser.get_current_page().find(
            'a', attrs={'class': 'lnk'}, text='Programme website')
    print('latest_episode_url: ',episode_page_url['href'])
    
    
    #navigate to episode page
    browser.open(BASE_URL + episode_page_url['href'])
    episode_page = browser.get_current_page()
    credits = episode_page.find('table', attrs={'class': 'table'})
    
    credits_dict = {}
    if credits is not None:
        for row in credits.find_all('tr'):
            person = row.find_all('span')
            if len(person) > 1:
                json_credits = [x.get_text() for x in person]
                credits_dict[json_credits[0]] = json_credits[1]
        print(credits_dict)

        
    
    similar = episode_page.find(
        'div', attrs={'class': 'footer__similar b-g-p component'})

    if similar is not None:
        sim = similar.find_all('div')
        genre_format = []

        for i in sim:
            genre_format.append(
                [[x.get_text(), x['href']] for x in i.find_all('a')])

        genre_dict={}
        prog_frmt_dict = {}
        genre = []
        prog_frmat = []

        for i in range(len(genre_format)):
            for j in range(len(genre_format[i])):
                if i == 0:
                    genre.append(genre_format[i][j])
                else:
                    prog_frmat.append(genre_format[i][j])

        print('genre: ', genre)
        print('format: ',prog_frmat)


    left_to_watch = episode_page.find(
        'div', attrs={'class': 'grid 1/3@bpw 1/4@bpe'})

    if left_to_watch is not None:
        left_to_watch_items = left_to_watch.find_all(
            'p', attrs={'class': 'episode-panel__meta'})

        if left_to_watch.find(
                'div', attrs={'class': "episode-panel__meta"}) is None:
            if left_to_watch_items[0].span is None:
                days_left = left_to_watch_items[0].get_text()
            else:
                days_left = left_to_watch_items[0].span.get_text()
            duration = left_to_watch_items[1].get_text()

        print('Left to watch: ', days_left,'duration: ' ,duration)
    
    
    
    long_synopsis = episode_page.find(
        'div', attrs={'class': 'synopsis-toggle__long'})

    if long_synopsis is not None:
        long_synopsis_paragraphs = [
            x.get_text() for x in long_synopsis.find_all('p')
        ]

        print('long_synopsis: ',long_synopsis_paragraphs)

    # Broadcast information:

    main_broadcast = episode_page.find(
        'div',
        attrs={
            'class':
            'grid 1/3@bpw2 1/3@bpe map__column map__column--2 map__column--last'
        })

    if main_broadcast is not None:
        date_last_aired = main_broadcast.find(
            'span',
            attrs={'class': 'broadcast-event__date text-base timezone--date'})
        time_last_aired = main_broadcast.find(
            'span', attrs={'class': 'timezone--time'})
        channel = main_broadcast.find(
            'div',
            attrs={
                'class':
                'programme__service box-link__elevated micro text--subtle'
            })
        if channel is not None:
            channel_text = channel.find('a').get_text()
        if channel is not None:
            channel_link = channel.find('a')['href']
        if date_last_aired is not None:
            date_last_aired = date_last_aired.get_text()
        if time_last_aired is not None:
            time_last_aired = time_last_aired.get_text()

        print('date: ', date_last_aired, 'Time: ', time_last_aired, 'Channel: ',
              channel_text, channel_link)
        
    # you may also like
    # navigate to : current page + /recommendations
    # scrape the same way as getting other episode data
    
    current_url = browser.get_url()
    
    browser.open(current_url + '/recommendations')
    
    recommend_page = browser.get_current_page()
    
    if recommend_page is not None:
    
        page_items = recommend_page.find('ol', attrs={'class': 'highlight-box-wrapper'})
        
        if page_items is not None: 
            list_items = page_items.find_all('li')
            for item in list_items:
                item_info = item.find('div', attrs={'class': 'programme__body'})
                link_1 = item_info.h4.a['href']
                link_2 = item_info.h4.a['resource']
                title = item_info.h4.a.get_text()
                synop = item_info.p.get_text()
                
                print('recommendations:', link_1, link_2, 'title: ',title, synop)
    
    
    episodes_link = episode_page.find(
        'a', attrs={
            'class': 'br-nav__link',
            'data-linktrack': 'nav_episodes'
        })
    
    if episodes_link is not None:
        episodes_link = episodes_link['href']

        print(episodes_link)
    
        browser.open(BASE_URL + episodes_link)
        
        
        episodes_page = browser.get_current_page()
        episodes_available_list = episodes_page.find(
            'div', attrs={'class': 'br-box-page programmes-page'})
        episodes_container_list = episodes_available_list.find_all(
            'div',
            attrs={
                'class':
                'programme programme--tv programme--episode block-link highlight-box--list br-keyline br-blocklink-page br-page-linkhover-onbg015--hover'
            })

        available_episodes = episodes_page.find('span', attrs={'class': 'hidden grid-visible@bpb2 grid-visible@bpw'})
        print('available episodes: ', available_episodes.get_text())
        
        for item in episodes_container_list:
            # link
            item_headder = item.find(
                'div', attrs={'class': 'cta cta__overlay'})
            item_link = item_headder.a['href']
            # time left
            item_time_left = item_headder.a['title']
            # title
            item_body = item.find('div', attrs={'class': 'programme__body'})
        
            print(item_link, item_time_left)
        
            if item_body is not None:
                # num of episodes
                try: 
                    episode_oneline_synopsis = item_body.p.get_text()
                    print('episode_oneline_synopsis: ' ,episode_oneline_synopsis)
                except:
                    pass
                try:
                    episode_no = item_body.p.abbr['title']
                    print('episode_no: ', episode_no)
                except:
                    pass
                try:
                    episode_title = item_body.find('span', attrs={'class': 'programme__title gamma'}).get_text()
                    print(episode_title)
                except:
                    pass
        
        
        episode_pagination = episode_page.find('ol', attrs={'class': 'nav nav--banner pagination delta'})
        
        print(episode_pagination)
        
        
        
        
        
    print('\n')
# Out:
# ('link: ', '/iplayer/episode/p02f7d2x/abadas-sgi')
# ('title: ', u'Abadas')
# ('synopsis: ', u'Rhaglen animeiddio i blant ifanc yn canolbwyntio ar gyflwyno geiriau newydd. Animation ...')
# ('latest_episode_url: ', '/programmes/p02b4jth')
# ('recommendations:', '/programmes/p02kfs3n', 'https://www.bbc.co.uk/programmes/p02kfs3n', 'title: ', u'  Pentre Bach  \u2014 Cyfres 1, Botwm Bol y Cyfrifiadur ', u" Mae'r papur bro lleol yn barod i gael ei argraffu, ond mae rhywbeth mawr yn bod ar y cy... ")
# ('recommendations:', '/programmes/p02bq50c', 'https://www.bbc.co.uk/programmes/p02bq50c', 'title: ', u'  Wibli Sochyn y Mochyn  \u2014 Llinyn ', u" Mae Wibli'n dod o hyd i ddarn o linyn ar y llawr ac yn ceisio dyfalu o ble mae'n dod. W... ")
# ('recommendations:', '/programmes/p02n81pj', 'https://www.bbc.co.uk/programmes/p02n81pj', 'title: ', u'  Ty M\xeal  \u2014 Cyfres 2014, Gardd Morgan ', u' Mae Morgan yn mynd ati i greu gardd flodau, ac yn dysgu bod rhaid bod yn amyneddgar. Mo... ')
# ('recommendations:', '/programmes/p02mx5jk', 'https://www.bbc.co.uk/programmes/p02mx5jk', 'title: ', u'  Twt  \u2014 Cyfres 1, Gweld yr Ochr Ddoniol ', u' Mae trigolion yr harbwr yn ceisio meddwl am rywbeth i godi calon Tanwen ond yn anffodus... ')
# ('recommendations:', '/programmes/p02gg30l', 'https://www.bbc.co.uk/programmes/p02gg30l', 'title: ', u"  Dwylo'r Enfys  \u2014 Cyfres 1, Maddison ", u" Mae Maddie o'r Rhondda yn gwneud gwaith pwysig ar y fferm gan roi llaeth i'r myn gafr b... ")
# ('recommendations:', '/programmes/p03fd7q8', 'https://www.bbc.co.uk/programmes/p03fd7q8', 'title: ', u'  Stiw  \u2014 Cyfres 2013, Stiw a Dydd Santes Dwynwen ', u" Mae Stiw'n gwneud cerdyn arbennig i roi i'r teulu i gyd ar Ddydd Santes Dwynwen. Stiw m... ")
# ('recommendations:', '/programmes/p02ft9pm', 'https://www.bbc.co.uk/programmes/p02ft9pm', 'title: ', u'  Sbridiri  \u2014 Cyfres 2, Crocodeil ', u' Yn y rhaglen hon mae Twm a Lisa yn creu tylwythen deg o flodau. Twm and Lisa make a flo... ')
# ('recommendations:', '/programmes/p02mlpph', 'https://www.bbc.co.uk/programmes/p02mlpph', 'title: ', u'  Y Crads Bach  \u2014 Llnau llanast ', u" Mae'n ddiwrnod heulog yn y gaeaf ac mae'r crads bach wedi drysu'n l\xe2n - ydy hi'n wanwyn... ")
# ('recommendations:', '/programmes/p02m8r88', 'https://www.bbc.co.uk/programmes/p02m8r88', 'title: ', u'  Boj  \u2014 Cyfres 2014, Cynaeafwyr Hapus ', u" Mae Boj a'i ffrindiau yn mynd i randir Mr Clipaclop i gynaeafu eu llysiau. Boj's buddie... ")
# ('recommendations:', '/programmes/p06xx8dq', 'https://www.bbc.co.uk/programmes/p06xx8dq', 'title: ', u'  Nos Da Cyw  \u2014 Cyfres 1, Cyw a Gwen y Gwdih\u0175 ', u" Mae'r haul yn mynd i'w wely ac mae'n amser i ni gael stori fach cyn cysgu. Heddiw - sto... ")
# /programmes/p02b4jth/episodes
# ('available episodes: ', u'(8)')
# ('https://www.bbc.co.uk/iplayer/episode/p02f7d2x', u'28 o ddyddiau ar \xf4l i wylio (Sad 23 Chwefror 2019, 09:00)')
# ('episode_oneline_synopsis: ', u"\nMae'r Abadas yn chwarae ym mhyllau mwdlyd yr ardd pan ddaw Ben ar eu traws a'u gwahodd ...\n")
# Sgi
# ('https://www.bbc.co.uk/iplayer/episode/p02f7cfh', u'26 o ddyddiau ar \xf4l i wylio (Iau 21 Chwefror 2019, 09:00)')
# ('episode_oneline_synopsis: ', u"\nMae gan Ben air Abada newydd sbon: 'melin wynt'. Ela gaiff ei dewis i fynd i chwilio am...\n")
# Melin Wynt
# ('https://www.bbc.co.uk/iplayer/episode/p02dzdxj', u'21 o ddyddiau ar \xf4l i wylio (Sad 16 Chwefror 2019, 09:00)')
# ('episode_oneline_synopsis: ', u"\nTybed a fydd gair heddiw, 'anrheg' yn helpu Ela gan nad oes ganddi degan arbennig? Ela'...\n")
# Anrheg
# ('https://www.bbc.co.uk/iplayer/episode/p02dtfvr', u'19 o ddyddiau ar \xf4l i wylio (Iau 14 Chwefror 2019, 09:00)')
# ('episode_oneline_synopsis: ', u"\nMae delwedd heddiw'n un arbennig iawn, gan fod angen tri gair i ddisgrifio 'crwban y mo...\n")
# Crwban y Môr
# ('https://www.bbc.co.uk/iplayer/episode/p02dtdtl', u'14 o ddyddiau ar \xf4l i wylio (Sad 09 Chwefror 2019, 09:00)')
# ('episode_oneline_synopsis: ', u"\nMae un o'r Abadas yn mynd ar antur gyffrous wrth edrych am rywbeth si\xe2p cylch gydag aro...\n")
# Oren
# ('https://www.bbc.co.uk/iplayer/episode/p02db5b3', u'12 o ddyddiau ar \xf4l i wylio (Iau 07 Chwefror 2019, 09:00)')
# ('episode_oneline_synopsis: ', u"\nYmunwch \xe2'r Abadas ar antur arbennig unwaith eto! 'Bwi' yw'r gair newydd heddiw. Today'...\n")
# Bwi
# ('https://www.bbc.co.uk/iplayer/episode/p02db4dt', u'7 o ddyddiau ar \xf4l i wylio (Sad 02 Chwefror 2019, 09:00)')
# ('episode_oneline_synopsis: ', u"\nMae'r Abadas wedi adeiladu ffau yn y ty i'w cadw'n sych rhag glaw papur Seren. Mae gan ...\n")
# Ambarél
# ('https://www.bbc.co.uk/iplayer/episode/p02d5p6q', u'21 awr ar \xf4l i wylio (Sad 26 Ionawr 2019, 08:50)')
# ('episode_oneline_synopsis: ', u"\nAr \xf4l adeiladu castell eira yn y mynyddoedd oer, mae'r Abadas yn ymuno \xe2 Ben i chwarae ...\n")
# Stôl
# None
#
#
# ('link: ', '/iplayer/episode/b03lyzpr/abba-at-the-bbc')
# ('title: ', u'ABBA at the BBC')
# ('synopsis: ', u'With Waterloo, Dancing Queen, Does Your Mother Know, SOS, Fernando, Chiquitita and more.')
# ('latest_episode_url: ', '/programmes/b03lyzpr')
# {u'Producer': u'Dione Newton'}
# ('genre: ', [[u'Music', '/programmes/genres/music'], [u'Classic Pop & Rock', '/programmes/genres/music/classicpopandrock']])
# ('format: ', [[u'Performances & Events', '/programmes/formats/performancesandevents']])
# ('Left to watch: ', u'3 days left to watch', 'duration: ', u'\n59 minutes\n            ')
# ('long_synopsis: ', [u"If you fancy an hour's worth of irresistible guilty pleasures from Anni-Frid, Benny, Bjorn and Agnetha, this is the programme for you. ABBA stormed the 1974 Eurovision song contest with their winning entry Waterloo, and this programme charts the meteoric rise of the band with some of their greatest performances at the BBC. ", u'It begins in 1974 with their first Top of the Pops appearance, and we even get to see the band entertaining holidaymakers in Torbay in a 1975 Seaside Special. There are many classic ABBA tunes from the 1979 BBC special ABBA in Switzerland, plus their final BBC appearance on the Late Late Breakfast show in 1982. ', u"This compilation is a must for all fans and includes great archive interviews, promos and performances of some of ABBA's classics including Waterloo, Dancing Queen, Does Your Mother Know, Thank You for the Music, SOS, Fernando, Chiquitita and many more."])
# ('date: ', u'Sun 30 Dec 2018', 'Time: ', u'00:00', 'Channel: ', u'BBC Four', 'https://www.bbc.co.uk/bbcfour')
# ('recommendations:', '/programmes/p06x6cwj', 'https://www.bbc.co.uk/programmes/p06x6cwj', 'title: ', u'  Sounds of the 80s with Gary Davies  \u2014 Melanie C ', u" Gary Davies presents a 'spicey' selection of 80's videos, with Melanie C. ")
# ('recommendations:', '/programmes/b00sxjls', 'https://www.bbc.co.uk/programmes/b00sxjls', 'title: ', u"  Forever Young: How Rock 'n' Roll Grew Up  ", u" Documentary looking at how rock 'n' roll has had to deal with growing up and growing old. ")
# ('recommendations:', '/programmes/m00023xl', 'https://www.bbc.co.uk/programmes/m00023xl', 'title: ', u'  Guitar, Drum and Bass  \u2014 Series 1, On Bass... Tina Weymouth! ', u" 2/3 Talking Heads' Tina Weymouth celebrates the contribution of the bass to popular music. ")
# ('recommendations:', '/programmes/b00hq4qr', 'https://www.bbc.co.uk/programmes/b00hq4qr', 'title: ', u'  Motown at the BBC  ', u' With The Miracles, The Supremes, Stevie Wonder, The Temptations and The Four Tops. ')
# ('recommendations:', '/programmes/b00zwrn5', 'https://www.bbc.co.uk/programmes/b00zwrn5', 'title: ', u'  Top of the Pops  \u2014 Big Hits: TOTP 1964 to 1975 ', u' With The Rolling Stones, Tom Jones, Status Quo, Procol Harum, Stevie Wonder and The Kinks. ')
# ('recommendations:', '/programmes/b04f86xk', 'https://www.bbc.co.uk/programmes/b04f86xk', 'title: ', u'  Kate Bush at the BBC  ', u' Including the hits Wuthering Heights, Babooshka, Running up That Hill and Hounds of Love. ')
# ('recommendations:', '/programmes/b04dzswb', 'https://www.bbc.co.uk/programmes/b04dzswb', 'title: ', u'  The Kate Bush Story: Running Up That Hill  ', u" Exploring Kate Bush's career and music through the testimony of collaborators and fans. ")
# ('recommendations:', '/programmes/b01psct4', 'https://www.bbc.co.uk/programmes/b01psct4', 'title: ', u'  Shirley Bassey at the BBC  ', u' Featuring The Performance of My Life, Goldfinger, Big Spender and Diamonds Are Forever. ')
# ('recommendations:', '/programmes/b09kkkbx', 'https://www.bbc.co.uk/programmes/b09kkkbx', 'title: ', u'  Elvis: The Rebirth of the King  ', u' Film arguing that Elvis reached his artistic peak in the early years of his Vegas period. ')
# ('recommendations:', '/programmes/b0b0g902', 'https://www.bbc.co.uk/programmes/b0b0g902', 'title: ', u'  Jeff Beck: Still on the Run  ', u' The story of guitar legend Jeff Beck and his career as a maverick in the music business. ')
#
#
# ('link: ', '/iplayer/episode/b0bxc1sn/the-abc-murders-series-1-episode-3')
# ('title: ', u'The ABC Murders')
# ('synopsis: ', u"It's 1933, and an older and greyer Hercule Poirot must take matters into his own hands.")
# ('latest_episode_url: ', '/programmes/b0bxc1sn#credits')
# {u'Author': u'Agatha Christie', u'Sir Carmichael Clarke': u'Christopher Villiers', u'Writer': u'Sarah Phelps', u'Rose Marbury': u'Shirley Henderson', u'Inspector Crome': u'Rupert Grint', u'Newsreader': u'Jonathan Keeble', u'Nurse': u'Gillian Waugh', u'Sergeant Yelland': u'Michael Shaeffer', u'Weddle': u'Alexander Kirk', u'German Officer': u'Ali Cook', u'Cust': u'Eamon Farren', u'Prynne': u'Henry Goodman', u'Lily Marbury': u'Anya Chalotra', u'Director': u'Alex Gabassi', u'Yvonne': u'Barbara Drennan', u'Lady Hermione Clarke': u'Tara Fitzgerald', u'Executive Producer': u'Elizabeth Kilgarriff', u'Production Company': u'Agatha Christie Productions Limited', u'Franklin Clarke': u'Andrew Buchan', u'Beautiful Young Man': u'Conrad McCroddan', u'Young Journalist': u'James Cooney', u'Hercule Poirot': u'John Malkovich', u'Betty Barnard': u'Eve Austin', u'Capstick': u'Suzanne Packer', u'Thora Grey': u'Freya Mavor', u'Producer': u'Farah Abushwesha', u'Jenny Barnard': u'Suzanne Packer', u'Donald Fraser': u'Jack Farthing', u'Megan Barnard': u'Bronwyn James'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-660f329c68ed> in <module>()
#      41
#      42     similar = episode_page.find(
# ---> 43         'div', attrs={'class': 'footer__similar b-g-p component'})
#      44
#      45     if similar is not None:
#
# /usr/local/lib/python2.7/site-packages/bs4/element.pyc in find(self, name, attrs, recursive, text, **kwargs)
#    1298         criteria."""
#    1299         r = None
# -> 1300         l = self.find_all(name, attrs, recursive, text, 1, **kwargs)
#    1301         if l:
#    1302             r = l[0]
#
# /usr/local/lib/python2.7/site-packages/bs4/element.pyc in find_all(self, name, attrs, recursive, text, limit, **kwargs)
#    1319         if not recursive:
#    1320             generator = self.children
# -> 1321         return self._find_all(name, attrs, text, limit, generator, **kwargs)
#    1322     findAll = find_all       # BS3
#    1323     findChildren = find_all  # BS2
#
# /usr/local/lib/python2.7/site-packages/bs4/element.pyc in _find_all(self, name, attrs, text, limit, generator, **kwargs)
#     634             except StopIteration:
#     635                 break
# --> 636             if i:
#     637                 found = strainer.search(i)
#     638                 if found:
#
# /usr/local/lib/python2.7/site-packages/bs4/element.pyc in __nonzero__(self)
#    1027         return x in self.contents
#    1028
# -> 1029     def __nonzero__(self):
#    1030         "A tag is non-None even if it has no contents."
#    1031         return True
#
# KeyboardInterrupt:

# %%
def iplayer_atoz_page_extractor():
    
    return 0

# %%
def episode_page_extractor():
    
    return 0

# %%
def programme_website_extractor():
    
    return 0

# %%
def recommendation_extraction():
    
    return 0

# %%
def episode_list_extraction():
    
    return 0

# %%
def dictionary_builder():
    
    return 0

# %%
base_url = 'https://www.bbc.co.uk/programmes/b007y6k8/'
url = 'https://www.bbc.co.uk/programmes/b007y6k8/episodes/player'

def episode_pagination_test():
    episode_page = browser.get_current_page()
    pagination = episode_page.find('ol', attrs={'class': 'nav nav--banner pagination delta'})
    
    page_list = pagination.find_all('li', attrs={'class': 'pagination__page'})
    
    curr_url = browser.get_url()
    
    page_links = [x.a['href'] for x in page_list if x.a is not None]
    
    browser.open(base_url + next_on_suffix)
    
    next_on = browser.get_current_page()
    next_on_section = next_on.find('ol', attrs={'class':'highlight-box-wrapper'}) 
    
    next_up_dict = {}
    
    for item in next_on_section.find_all('li'):
        broadcast_info = item.find('div', attrs={'class':'programme__body programme__body--flush'})
        broadcast_info_tag = broadcast_info.find('div', attrs={'class': 'broadcast-event__time beta'})
        
        broadcast_date = broadcast_info_tag['title']
        broadcast_day = broadcast_info_tag.find('span', attrs={'class':'broadcast-event__date text-base timezone--date'}).get_text()
        broadcast_time = broadcast_info_tag.find('span',attrs = {'class': 'timezone--time'}).get_text()
        
        broadcast_channel = broadcast_info.find('div', attrs={'class': 'programme__service box-link__elevated micro text--subtle'})

        channel = broadcast_channel.a.get_text()
        channel_url = broadcast_channel.a['href']
        
        program_info = item.find('div', attrs={'class': 'grid 7/12 2/3@bpb2 3/4@bpw 5/6@bpw2 5/6@bpe'})
        program_title_info = program_info.a
        
        program_id = program_info.div['data-pid']
        program_link = program_title_info['href']
        program_title = program_title_info.find('span', attrs={'class': 'programme__title gamma'}).get_text()
        series = program_title_info.find('span', attrs={'class': 'programme__subtitle centi'}).get_text()
        program_synopsis = program_info.p.get_text()
        
        next_up_dict[program_id] = {'program_title': program_title.encode('utf-8'),
                                    'series': series.encode('utf-8'),
                                    'program_synopsis': program_synopsis.encode('utf-8').strip(),
                                    'program_link': program_link.encode('utf-8'),
                                    'channel': {'name': channel.encode('utf-8'),
                                              'link': channel_link.encode('utf-8')},
                                    'broadcast': {'date': broadcast_date.encode('utf-8'),
                                                 'day': broadcast_day.encode('utf-8'),
                                                 'time': broadcast_time.encode('utf-8')}}
        
        
    print(next_up_dict)

# %%
base_url = 'https://www.bbc.co.uk/programmes/b007y6k8/'
episodes_suffix = 'episodes/'
next_on_suffix = 'broadcasts/upcoming/'

browser.open(base_url + episodes_suffix)


episode_pagination_test()
# Out:
# {'b0c1tq4b': {'series': 'Series 22', 'broadcast': {'date': '28 Jan 2019', 'day': 'Monday', 'time': '21:00'}, 'program_link': 'https://www.bbc.co.uk/programmes/b0c1tq4b', 'program_synopsis': 'A shocking incident on a suburban street brings back painful memories for Jack.', 'program_title': 'Deathmaker, Part One', 'channel': {'link': 'https://www.bbc.co.uk/bbcfour', 'name': 'BBC One'}}, 'b0c2ks57': {'series': 'Series 22', 'broadcast': {'date': '04 Feb 2019', 'day': 'Mon 4 Feb 2019', 'time': '21:00'}, 'program_link': 'https://www.bbc.co.uk/programmes/b0c2ks57', 'program_synopsis': 'Nikki is humiliated in court when a barrister accuses her of making a serious error.', 'program_title': 'Betrayal, Part One', 'channel': {'link': 'https://www.bbc.co.uk/bbcfour', 'name': 'BBC One'}}, 'b0c2ksxl': {'series': 'Series 22', 'broadcast': {'date': '05 Feb 2019', 'day': 'Tue 5 Feb 2019', 'time': '21:00'}, 'program_link': 'https://www.bbc.co.uk/programmes/b0c2ksxl', 'program_synopsis': 'When Thomas sides against her findings on a controversial case, Nikki suspects foul play.', 'program_title': 'Betrayal, Part Two', 'channel': {'link': 'https://www.bbc.co.uk/bbcfour', 'name': 'BBC One'}}, 'b0c1tr0k': {'series': 'Series 22', 'broadcast': {'date': '29 Jan 2019', 'day': 'Tuesday', 'time': '21:00'}, 'program_link': 'https://www.bbc.co.uk/programmes/b0c1tr0k', 'program_synopsis': "The team's search for the killer uncovers links to the Troubles in Northern Ireland.", 'program_title': 'Deathmaker, Part Two', 'channel': {'link': 'https://www.bbc.co.uk/bbcfour', 'name': 'BBC One'}}}
